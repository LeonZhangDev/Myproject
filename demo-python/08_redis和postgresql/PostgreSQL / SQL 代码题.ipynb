# %% [markdown]
# CREATE TABLE users (id SERIAL PRIMARY KEY, name VARCHAR(100), age INTEGER, city VARCHAR(100));

# %% [markdown]
# SELECT id, name, age, city FROM users WHERE age >= 18 AND city = 'Chengdu' ORDER BY age DESC;

# %% [markdown]
# SELECT * FROM users ORDER BY id LIMIT 10 OFFSET 20;

# %% [markdown]
# SELECT tasks.id,tasks.title,users.name FROM tasks JOIN users ON tasks.user_id = users.id;

# %% [markdown]
# SELECT tasks.id,tasks.title,users.name FROM tasks JOIN users ON tasks.user_id = users.id;

# %% [markdown]
# SELECT users.id,users.name,tasks.title FROM users LEFT JOIN tasks ON users.id=tasks.user_id;

# %% [markdown]
# SELECT users.id,users.name, COUNT(tasks.id) AS task_count FROM users LEFT JOIN tasks ON users.id = tasks.user_id GROUP BY users.id,users.name;

# %% [markdown]
# SELECT users.id, users.name, COUNT(tasks.id) AS task_count FROM users LEFT JOIN tasks ON users.id = tasks.user_id GROUP BY users.id, users.name HAVING COUNT(tasks.id) >= 5;q

# %% [markdown]
# SELECT *
# FROM tasks
# WHERE user_id = 1
# ORDER BY created_at DESC;

# %% [markdown]
# CREATE INDEX idx_tasks_user_created
# ON tasks (
#     user_id,
#     created_at DESC
# );
